# %%
import cv2
import sys
import logging as log
import datetime as dt
from time import sleep
import numpy as np
#检测视频
while True:
    ret,frame = cap.read()
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    ret,binary = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

    contours,hirearchy = cv2.findContours(binary,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(frame,contours,-1,(255,0,255),1)
    cv2.imshow('frame',frame)
    c = cv2.waitKey(1)
    if c == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()


cascPath = "D:/Anaconda5.2.0/Lib/site-packages/cv2/data/haarcascade_frontalface_default.xml"
faceCascade = cv2.CascadeClassifier(cascPath)


# 打开视频捕获设备
video_capture = cv2.VideoCapture(0)

while True:
    if not video_capture.isOpened():
        print('Unable to load camera.')
        sleep(5)
        pass

        # 读视频帧
    ret, frame = video_capture.read()
    
    # 转为灰度图像
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 调用分类器进行检测
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(10, 10),
        # flags=cv2.cv.CV_HAAR_SCALE_IMAGE
    )
   
    # 画矩形框
    for (x, y, w, h) in faces:
        print(x, y, w, h)
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 1)#x ,y 
        # 显示视频
    ##磨皮美白算法dst = cv2.bilateralFilter(img, 15, 35, 35)
   # cv2.bilateralFilter
    cv2.resizeWindow('Video', 640,480 )
    cv2.imshow('Video', frame)
    
    if cv2.waitKey(60) & 0xFF == ord('q'):
        break


        # 关闭摄像头设备
video_capture.release()

# 关闭所有窗口
cv2.destroyAllWindows()
# Out:
# 252 54 176 176
# 259 76 160 160
# 254 76 163 163
# 251 121 166 166
# 246 128 173 173
# 248 125 178 178
# 253 116 164 164
# 256 100 157 157
# 291 56 160 160
# 254 108 158 158
# 257 171 148 148
# 291 214 124 124
# 275 273 114 114
# 322 306 99 99
# 285 307 100 100
# 321 335 81 81
# 310 294 73 73
# 310 274 65 65
# 300 249 66 66
# 295 233 66 66
# 290 213 68 68
# 288 194 72 72
# 289 189 69 69
# 291 180 70 70
# 290 163 70 70
# 287 166 68 68
# 282 165 67 67
# 280 160 66 66
# 281 160 62 62
# 280 170 60 60
# 281 183 60 60
# 285 189 58 58
# 295 182 56 56
# 305 169 56 56
# 310 171 58 58
# 310 171 58 58
# 310 169 57 57
# 310 167 57 57
# 308 167 56 56
# 122 296 33 33
# 308 166 54 54
# 126 291 31 31
# 305 156 57 57
# 306 157 55 55
# 306 158 55 55
# 305 159 50 50
# 306 164 55 55
# 311 177 52 52
# 308 181 50 50
# 303 190 54 54
# 299 182 55 55
# 298 195 49 49
# 298 203 55 55
# 303 201 51 51
# 302 201 52 52
# 301 200 53 53
# 300 195 52 52
# 224 292 63 63
# 302 179 51 51
# 298 168 54 54
# 301 178 50 50
# ...
